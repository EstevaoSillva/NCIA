# %%
import cv2

image_noel = cv2.imread('ATIVIDADES/PDI_NOEL/PapaiNoel.jpeg')
# Out:
# Mailcap files:
# 	/home/estevaosilva/.mailcap
# 	/etc/mailcap
# 	/usr/etc/mailcap
# 	/usr/local/etc/mailcap
#
# Mailcap entries:
# /tmp/ipykernel_14934/1022333284.py:1: DeprecationWarning: The mailcap module is deprecated and will be removed in Python 3.13. See the mimetypes module for an alternative.
#   from mailcap import show
# [ WARN:0@0.022] global loadsave.cpp:275 findDecoder imread_('ATIVIDADES/PDI_NOEL/PapaiNoel.jpeg'): can't open/read file: check file path/integrity
