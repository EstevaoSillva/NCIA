# %%
import pandas as pd

data = {
    "Cidade": [
        "Manaus", "Maceió", "Curitiba", "Aracaju", "São Paulo"
    ],
    "População": [
        2100000, 3300000, 1773718, 628849, 11895578
    ],
    "Estado": [
        "Amazonas", "Alagoas", "Paraná", "Sergipe", "São Paulo"
    ],
    "Região": [
        "Norte", "Nordeste", "Sul", "Nordeste", "Sudeste"
    ],
}

print(data)

df = pd.DataFrame(data)
print(df)


df2 = pd.DataFrame(data, columns=["Cidade", "População", "Estado", "Região", "PIB"])
print("\n", df2)

df2.describe()
print("\n", df2)
# Out:
# {'Cidade': ['Manaus', 'Maceió', 'Curitiba', 'Aracaju', 'São Paulo'], 'População': [2100000, 3300000, 1773718, 628849, 11895578], 'Estado': ['Amazonas', 'Alagoas', 'Paraná', 'Sergipe', 'São Paulo'], 'Região': ['Norte', 'Nordeste', 'Sul', 'Nordeste', 'Sudeste']}
#       Cidade  População     Estado    Região
# 0     Manaus    2100000   Amazonas     Norte
# 1     Maceió    3300000    Alagoas  Nordeste
# 2   Curitiba    1773718     Paraná       Sul
# 3    Aracaju     628849    Sergipe  Nordeste
# 4  São Paulo   11895578  São Paulo   Sudeste
#
#        Cidade  População     Estado    Região  PIB
# 0     Manaus    2100000   Amazonas     Norte  NaN
# 1     Maceió    3300000    Alagoas  Nordeste  NaN
# 2   Curitiba    1773718     Paraná       Sul  NaN
# 3    Aracaju     628849    Sergipe  Nordeste  NaN
# 4  São Paulo   11895578  São Paulo   Sudeste  NaN
#
#        Cidade  População     Estado    Região  PIB
# 0     Manaus    2100000   Amazonas     Norte  NaN
# ...
